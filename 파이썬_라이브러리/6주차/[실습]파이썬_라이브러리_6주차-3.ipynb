# %%
#판다스 실습

# %%
import pandas as pd

# %%
order_items_df = pd.read_csv("archive/order_items.csv")

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          112650 non-null  object
#  1   order_item_id     112650 non-null  int64
#  2   product_id        112650 non-null  object
#  3   seller_id         112650 non-null  object
#  4   price             112650 non-null  float64
#  5   shipping_charges  112650 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.2+ MB

# %%
order_items_df.isnull().sum()
# Out:
# order_id            0
# order_item_id       0
# product_id          0
# seller_id           0
# price               0
# shipping_charges    0
# dtype: int64

# %%
payment_df = pd.read_csv("archive/payments.csv")

# %%
payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
payment_df.duplicated().sum()
# Out:
# 0

# %%
order_items_df.duplicated().sum()
# Out:
# 0

# %%
customers_df = pd.read_csv("archive/customers.csv")

# %%
customers_df.duplicated().sum()
# Out:
# 3089

# %%
#customers.csv 결측치 확인
customers_df.isnull().sum()
# Out:
# customer_id                 0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
#orders.csv 불러오기
orders_df = pd.read_csv("archive/orders.csv")

# %%
#orders.csv 결측치 확인
orders_df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_timestamp        2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
#orders.csv 정보 확인
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_timestamp      96476 non-null  object
#  6   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(7)
# memory usage: 5.3+ MB

# %%
#products.csv 데이터 가져오기
products_df = pd.read_csv("archive/products.csv")

# %%
#products.csv 정보 확인
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32781 non-null  object
#  2   product_weight_g       32949 non-null  float64
#  3   product_length_cm      32949 non-null  float64
#  4   product_height_cm      32949 non-null  float64
#  5   product_width_cm       32949 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 1.5+ MB

# %%
#products.csv 결측치 확인
products_df.isnull().sum()
# Out:
# product_id                 0
# product_category_name    170
# product_weight_g           2
# product_length_cm          2
# product_height_cm          2
# product_width_cm           2
# dtype: int64

# %%
#null 값이 한 개 이상인 데이터만 보고샆은 경우(전체열)
products_df ["missing_count"] = products_df.isnull().sum(axis =1)

# %%
#필터링
filtered_df = products_df[products_df["missing_count"] > 0]

# %%
#출력
filtered_df
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 8230   fe34503c6bccf918db601aaafd4a975a                   NaN
# 8291   0c877471e35049402bca235e06cb8063                   NaN
# 8332   1574ed2c73e4465c572f68dd77528203                   NaN
# 8578   09ff539a621711667c43eba6a3bd8466                  toys
# 18851  5eb564652db742ff8f28759cd8d2652a                  toys
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 105               650.0               17.0               14.0
# 128               300.0               16.0                7.0
# ...

# %%
#겹치는 값 확인
products_df.duplicated().sum()
# Out:
# 0

# %%
import pandas as pd

#orders 데이터프레임
orders_df = pd.DataFrame({
    'order_id': [1,2,3],
    'customer_id': [101,102,103],
    'order_total': [150,200,300]
})

#customers 데이터프레임
customers_df = pd.DataFrame ({
    'customer_id': [101,102,103,104],
    'customer_name': ['Alice','Alicia','Bob','Charlie']
})

print("orders DataFrame:")
print(orders_df)
print("\ncustomers DataFrame:")
print(customers_df)

#Left Join 수행
merged_df = pd.merge(orders_df, customers_df, on = 'customer_id', how = 'left')

print("\nMerged DataFrame (LEFT JOIN 결과):")
print(merged_df)
# Out:
# orders DataFrame:
#    order_id  customer_id  order_total
# 0         1          101          150
# 1         2          102          200
# 2         3          103          300
#
# customers DataFrame:
#    customer_id customer_name
# 0          101         Alice
# 1          102        Alicia
# 2          103           Bob
# 3          104       Charlie
#
# Merged DataFrame (LEFT JOIN 결과):
#    order_id  customer_id  order_total customer_name
# 0         1          101          150         Alice
# 1         2          102          200        Alicia
# 2         3          103          300           Bob

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
#중복치 확인
customers_df.duplicated().sum()
# Out:
# 0

# %%
customers_df = customers_df.drop_duplicates()

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    4 non-null      int64
#  1   customer_name  4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
customers_df.duplicated().sum()
# Out:
# 0

# %%
import pandas as pd

# %%
customers_df = pd.read_csv("archive/customers.csv")
customers_df = customers_df.drop_duplicates()
order_items_df = pd.read_csv("archive/order_items.csv")
orders_df = pd.read_csv("archive/orders.csv")
payments_df = pd.read_csv("archive/payments.csv")
products_df = pd.read_csv("archive/products.csv")

print(payments_df.duplicated().sum())
print(payments_df.isnull().sum())
print(order_items_df.duplicated().sum())
print(order_items_df.isnull().sum())
print(orders_df.duplicated().sum())
print(orders_df.isnull().sum())

print(payments_df.info())
print(order_items_df.info())
print(orders_df.info())
# Out:
# 0
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
# 0
# order_id            0
# order_item_id       0
# product_id          0
# seller_id           0
# price               0
# shipping_charges    0
# dtype: int64
# 0
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_timestamp        2965
# order_estimated_delivery_date       0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
# ...

# %%
merged = pd.merge(orders_df, payments_df, how = 'left', on = 'order_id')
merged = pd.merge(merged, customers_df, how = 'left', on = 'customer_id')
merged = pd.merge(merged, order_items_df, how = 'left', on = 'order_id')
merged = pd.merge(merged, products_df, how = 'left', on = 'product_id')

# %%
merged.duplicated().sum()
# Out:
# 0

# %%
merged.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 178
# order_delivered_timestamp        3422
# order_estimated_delivery_date       0
# payment_sequential                  3
# payment_type                        3
# payment_installments                3
# payment_value                       3
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# order_item_id                     835
# product_id                        835
# seller_id                         835
# price                             835
# shipping_charges                  835
# product_category_name            1267
# product_weight_g                  855
# product_length_cm                 855
# product_height_cm                 855
# product_width_cm                  855
# dtype: int64

# %%
merged = merged.dropna()
merged.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_timestamp        0
# order_estimated_delivery_date    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# price                            0
# shipping_charges                 0
# product_category_name            0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# dtype: int64

# %%
grouped_1 = merged.groupby(by = ["order_id","order_item_id"]).agg({"price": "mean", "shipping_charges": "mean"})

# %%
grouped_1
# Out:
#                                                  price  shipping_charges
# order_id                         order_item_id
# 00010242fe8c5a6d1ba2dd792cb16214 1.0             58.90             13.29
# 00018f77f2f0320c557190d7a144bdd3 1.0            239.90             19.93
# 000229ec398224ef6ca0657da4fc703e 1.0            199.00             17.87
# 00024acbcdf0a6daa1e931b038114c75 1.0             12.99             12.79
# 00042b26cf59d7ce69dfabb4e55b4fd9 1.0            199.90             18.14
# ...                                                ...               ...
# fffc94f6ce00a00581880bf54a75a037 1.0            299.99             43.41
# fffcd46ef2263f404302a634eb57f7eb 1.0            350.00             36.53
# fffce4705a9662cd70adb13d4a31832d 1.0             99.90             16.95
# fffe18544ffabc95dfada21779c9644f 1.0             55.99              8.72
# fffe41c64501cc87c801fd61db3f6244 1.0             43.00             12.79
#
# [109785 rows x 2 columns]

# %%
grouped_1 = grouped_1.groupby(by = ["order_id"]).agg({"price":"sum","shipping_charges":"sum"})

# %%
grouped_1
# Out:
#                                    price  shipping_charges
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214   58.90             13.29
# 00018f77f2f0320c557190d7a144bdd3  239.90             19.93
# 000229ec398224ef6ca0657da4fc703e  199.00             17.87
# 00024acbcdf0a6daa1e931b038114c75   12.99             12.79
# 00042b26cf59d7ce69dfabb4e55b4fd9  199.90             18.14
# ...                                  ...               ...
# fffc94f6ce00a00581880bf54a75a037  299.99             43.41
# fffcd46ef2263f404302a634eb57f7eb  350.00             36.53
# fffce4705a9662cd70adb13d4a31832d   99.90             16.95
# fffe18544ffabc95dfada21779c9644f   55.99              8.72
# fffe41c64501cc87c801fd61db3f6244   43.00             12.79
#
# [96139 rows x 2 columns]

# %%
grouped_2 = merged.groupby(by = ['order_id', 'payment_sequential']).agg({'payment_value':'mean'})
grouped_2 = grouped_2.groupby(by = ['order_id']).agg({'payment_value':'sum'})
grouped_2
# Out:
#                                   payment_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214          72.19
# 00018f77f2f0320c557190d7a144bdd3         259.83
# 000229ec398224ef6ca0657da4fc703e         216.87
# 00024acbcdf0a6daa1e931b038114c75          25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                         ...
# fffc94f6ce00a00581880bf54a75a037         343.40
# fffcd46ef2263f404302a634eb57f7eb         386.53
# fffce4705a9662cd70adb13d4a31832d         116.85
# fffe18544ffabc95dfada21779c9644f          64.71
# fffe41c64501cc87c801fd61db3f6244          55.79
#
# [96139 rows x 1 columns]

# %%
grouped_merge = pd.merge(grouped_1, grouped_2, on = 'order_id', how='left')

# %%
grouped_merge
# Out:
#                                    price  shipping_charges  payment_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214   58.90             13.29          72.19
# 00018f77f2f0320c557190d7a144bdd3  239.90             19.93         259.83
# 000229ec398224ef6ca0657da4fc703e  199.00             17.87         216.87
# 00024acbcdf0a6daa1e931b038114c75   12.99             12.79          25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9  199.90             18.14         218.04
# ...                                  ...               ...            ...
# fffc94f6ce00a00581880bf54a75a037  299.99             43.41         343.40
# fffcd46ef2263f404302a634eb57f7eb  350.00             36.53         386.53
# fffce4705a9662cd70adb13d4a31832d   99.90             16.95         116.85
# fffe18544ffabc95dfada21779c9644f   55.99              8.72          64.71
# fffe41c64501cc87c801fd61db3f6244   43.00             12.79          55.79
#
# [96139 rows x 3 columns]

# %%
(grouped_merge["price"] + grouped_merge["shipping_charges"] == grouped_merge["payment_value"]).sum()
# Out:
# 76885

# %%
(grouped_merge["price"] + grouped_merge["shipping_charges"] != grouped_merge["payment_value"]).sum()
# Out:
# 19254

# %%
#0 이상의 오차를 갖는 행의 개수
(grouped_merge["price"] + grouped_merge["shipping_charges"] - grouped_merge["payment_value"] >0).sum()
# Out:
# 9525

# %%
(abs(grouped_merge["price"] + grouped_merge["shipping_charges"] - grouped_merge["payment_value"]) >0).sum()
# Out:
# 19254

# %%
((grouped_merge["price"] + grouped_merge["shipping_charges"] != grouped_merge["payment_value"]) >0).sum()
# Out:
# 19254

# %%
(abs(grouped_merge["price"] + grouped_merge["shipping_charges"] - grouped_merge["payment_value"]) >0.01).sum()
# Out:
# 400

# %%
(abs(grouped_merge["price"] + grouped_merge["shipping_charges"] - grouped_merge["payment_value"]) >0.1).sum()
# Out:
# 272

# %%
merged.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_timestamp        0
# order_estimated_delivery_date    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# price                            0
# shipping_charges                 0
# product_category_name            0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# dtype: int64

# %%
merged.duplicated().sum()
# Out:
# 0

# %%
#파생변수 만들기
merged["product_volume"] = merged["product_length_cm"] * merged["product_height_cm"] * merged["product_width_cm"]

# %%
merged.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 2  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 3  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 4  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered          10/2/2017 10:56 2017-10-02 11:07:00
# 1    delivered          10/2/2017 10:56 2017-10-02 11:07:00
# 2    delivered          10/2/2017 10:56 2017-10-02 11:07:00
# 3    delivered          7/24/2018 20:41 2018-07-26 03:24:00
# 4    delivered            8/8/2018 8:38 2018-08-08 08:55:00
#
#   order_delivered_timestamp order_estimated_delivery_date  payment_sequential  \
# 0       2017-10-10 21:25:00                    2017-10-18                 1.0
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115289 non-null  object
#  1   customer_id                    115289 non-null  object
#  2   order_status                   115289 non-null  object
#  3   order_purchase_timestamp       115289 non-null  object
#  4   order_approved_at              115289 non-null  datetime64[ns]
#  5   order_delivered_timestamp      115289 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  115289 non-null  datetime64[ns]
#  7   payment_sequential             115289 non-null  float64
#  8   payment_type                   115289 non-null  object
#  9   payment_installments           115289 non-null  float64
#  10  payment_value                  115289 non-null  float64
# ...

# %%
merged["order_delivered_timestamp"] = pd.to_datetime(merged["order_delivered_timestamp"])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115289 non-null  object
#  1   customer_id                    115289 non-null  object
#  2   order_status                   115289 non-null  object
#  3   order_purchase_timestamp       115289 non-null  object
#  4   order_approved_at              115289 non-null  datetime64[ns]
#  5   order_delivered_timestamp      115289 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  115289 non-null  datetime64[ns]
#  7   payment_sequential             115289 non-null  float64
#  8   payment_type                   115289 non-null  object
#  9   payment_installments           115289 non-null  float64
#  10  payment_value                  115289 non-null  float64
# ...

# %%
merged["order_approved_at"] = pd.to_datetime(merged["order_approved_at"])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115289 non-null  object
#  1   customer_id                    115289 non-null  object
#  2   order_status                   115289 non-null  object
#  3   order_purchase_timestamp       115289 non-null  object
#  4   order_approved_at              115289 non-null  datetime64[ns]
#  5   order_delivered_timestamp      115289 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  115289 non-null  datetime64[ns]
#  7   payment_sequential             115289 non-null  float64
#  8   payment_type                   115289 non-null  object
#  9   payment_installments           115289 non-null  float64
#  10  payment_value                  115289 non-null  float64
# ...

# %%
merged["order_purchase_timestamp"] = pd.to_datetime(merged["order_purchase_timestamp"])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115289 non-null  object
#  1   customer_id                    115289 non-null  object
#  2   order_status                   115289 non-null  object
#  3   order_purchase_timestamp       115289 non-null  datetime64[ns]
#  4   order_approved_at              115289 non-null  datetime64[ns]
#  5   order_delivered_timestamp      115289 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  115289 non-null  datetime64[ns]
#  7   payment_sequential             115289 non-null  float64
#  8   payment_type                   115289 non-null  object
#  9   payment_installments           115289 non-null  float64
#  10  payment_value                  115289 non-null  float64
# ...

# %%
merged["order_estimated_delivery_date"] = pd.to_datetime(merged["order_estimated_delivery_date"])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115289 non-null  object
#  1   customer_id                    115289 non-null  object
#  2   order_status                   115289 non-null  object
#  3   order_purchase_timestamp       115289 non-null  datetime64[ns]
#  4   order_approved_at              115289 non-null  datetime64[ns]
#  5   order_delivered_timestamp      115289 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  115289 non-null  datetime64[ns]
#  7   payment_sequential             115289 non-null  float64
#  8   payment_type                   115289 non-null  object
#  9   payment_installments           115289 non-null  float64
#  10  payment_value                  115289 non-null  float64
# ...

# %%
merged["delivered_time"] = merged["order_delivered_timestamp"] - merged["order_purchase_timestamp"]

# %%
merged
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1       e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 2       e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 3       53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 4       47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# ...                                  ...                               ...
# 119155  63943bddc261676b46f01ca7ac2f7bd8  da62f9e57a76d978d02ab5362c509660
# 119156  83c1379a015df1e13d02aae0204711ab  737520a9aad80b3fbbdad19b66b37b30
# 119157  11c177c8e97725db2631073c19f07b62  5097a5312c8b157bb7be58ae360ef43c
# 119158  11c177c8e97725db2631073c19f07b62  5097a5312c8b157bb7be58ae360ef43c
# 119159  66dea50a8b16d9b4dee7af250b4be1a5  60350aa974b26ff12caad89e55993bd6
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
#이상치 처리(IQR 활용)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115289 non-null  object
#  1   customer_id                    115289 non-null  object
#  2   order_status                   115289 non-null  object
#  3   order_purchase_timestamp       115289 non-null  datetime64[ns]
#  4   order_approved_at              115289 non-null  datetime64[ns]
#  5   order_delivered_timestamp      115289 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  115289 non-null  datetime64[ns]
#  7   payment_sequential             115289 non-null  float64
#  8   payment_type                   115289 non-null  object
#  9   payment_installments           115289 non-null  float64
#  10  payment_value                  115289 non-null  float64
# ...

# %%
#숫자형 컬럼만 추출
numeric_columns = merged.select_dtypes(include=['number'])

#IQR 방법을 적용하여 이상치 탐지
for column in numeric_columns:
    Q1 = numeric_columns[column].quantile(0.25)
    Q3 = numeric_columns[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(f"column: {column}")
    print(f"Lower bound: {lower_bound}, Upper bound: {upper_bound}")

    #이상치 필터링
    outliers = merged[(numeric_columns[column] < lower_bound) | (numeric_columns[column] > upper_bound)]
    print("Outliers detected:")
    print(outliers)
    print("\n")

#데이터 특성 분석
#논리 기준
#이상치
# Out:
# column: payment_sequential
# Lower bound: 1.0, Upper bound: 1.0
# Outliers detected:
#                                 order_id                       customer_id  \
# 1       e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 2       e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 11      e69bfb5eb88e0ed6a785585b27e16dbf  299905e3934e9e181bfb2e164dd4b4f8
# 23      83018ec114eee8641c97e08f7b4e926f  634f09f6075fe9032e6c19609ffe995a
# 24      83018ec114eee8641c97e08f7b4e926f  634f09f6075fe9032e6c19609ffe995a
# ...                                  ...                               ...
# 119047  4bafa54db6b060da198f23f810835969  6e11aa7fefec6405ba35e05a8c0f9b0e
# 119048  4bafa54db6b060da198f23f810835969  6e11aa7fefec6405ba35e05a8c0f9b0e
# 119149  9115830be804184b91f5c00f6f49f92d  c716cf2b5b86fb24257cffe9e7969df8
# 119150  9115830be804184b91f5c00f6f49f92d  c716cf2b5b86fb24257cffe9e7969df8
# ...

# %%
merged.nunique()
# Out:
# order_id                         96139
# customer_id                      93041
# order_status                         2
# order_purchase_timestamp         86076
# order_approved_at                49330
# order_delivered_timestamp        75427
# order_estimated_delivery_date      444
# payment_sequential                  26
# payment_type                         4
# payment_installments                24
# payment_value                    28483
# customer_zip_code_prefix         14881
# customer_city                     4081
# customer_state                      27
# order_item_id                       21
# product_id                       32047
# seller_id                         2961
# price                             5835
# shipping_charges                  6917
# product_category_name               70
# product_weight_g                  2170
# product_length_cm                   99
# product_height_cm                  102
# product_width_cm                    94
# ...

# %%
merged = pd.get_dummies(merged, columns = ["payment_type"])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115289 non-null  object
#  1   customer_id                    115289 non-null  object
#  2   order_status                   115289 non-null  object
#  3   order_purchase_timestamp       115289 non-null  datetime64[ns]
#  4   order_approved_at              115289 non-null  datetime64[ns]
#  5   order_delivered_timestamp      115289 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  115289 non-null  datetime64[ns]
#  7   payment_sequential             115289 non-null  float64
#  8   payment_installments           115289 non-null  float64
#  9   payment_value                  115289 non-null  float64
#  10  customer_zip_code_prefix       115289 non-null  int64
# ...

# %%
merged = pd.get_dummies(merged, columns = ["product_category_name"])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 98 columns):
#  #   Column                                                         Non-Null Count   Dtype
# ---  ------                                                         --------------   -----
#  0   order_id                                                       115289 non-null  object
#  1   customer_id                                                    115289 non-null  object
#  2   order_status                                                   115289 non-null  object
#  3   order_purchase_timestamp                                       115289 non-null  datetime64[ns]
#  4   order_approved_at                                              115289 non-null  datetime64[ns]
#  5   order_delivered_timestamp                                      115289 non-null  datetime64[ns]
#  6   order_estimated_delivery_date                                  115289 non-null  datetime64[ns]
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
numeric_columns = merged.select_dtypes(include=['number'])
numeric_columns.info()
#scaled_data = scaler.fit_transform(numeric_columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115289 entries, 0 to 119159
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   payment_sequential        115289 non-null  float64
#  1   payment_installments      115289 non-null  float64
#  2   payment_value             115289 non-null  float64
#  3   customer_zip_code_prefix  115289 non-null  int64
#  4   order_item_id             115289 non-null  float64
#  5   price                     115289 non-null  float64
#  6   shipping_charges          115289 non-null  float64
#  7   product_weight_g          115289 non-null  float64
#  8   product_length_cm         115289 non-null  float64
#  9   product_height_cm         115289 non-null  float64
#  10  product_width_cm          115289 non-null  float64
#  11  product_volume            115289 non-null  float64
#  12  delivered_time            115289 non-null  timedelta64[ns]
# ...

# %%
numeric_columns = merged.select_dtypes(include=['number'])
scaled_data = scaler.fit_transform(merged[["delivered_time"]])

# %%
scaled_data
# Out:
# array([[-0.4286692 ],
#        [-0.4286692 ],
#        [-0.4286692 ],
#        ...,
#        [ 0.48821231],
#        [ 0.48821231],
#        [-0.50949906]])

# %%
merged["delivered_time"] = scaled_data

# %%
merged["delivered_time"]
# Out:
# 0        -0.428669
# 1        -0.428669
# 2        -0.428669
# 3         0.137950
# 4        -0.327153
#             ...
# 119155    1.029655
# 119156    1.312265
# 119157    0.488212
# 119158    0.488212
# 119159   -0.509499
# Name: delivered_time, Length: 115289, dtype: float64
