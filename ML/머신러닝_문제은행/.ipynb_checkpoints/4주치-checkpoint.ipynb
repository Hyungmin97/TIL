# %% [markdown]
# # 비지도학습 기법을 활용한 최적의 2군집 찾기 모델!
# ### 요구 사항
#
# 타이타닉 데이터셋에서 생존 여부 레이블을 제외한 후, 비지도학습을 사용하여 데이터를 두 개의 군집으로 나누고, 실제 생존 여부와의 비교를 통해 군집화 성능을 평가합니다.
#
# - 타이타닉 데이터셋 을 준비 후 전처리를 진행해주세요
# (https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv)
# - 레이블을 제외 후 비지도 군집화 모델을 학습!
# - 그 후 실제 레이블과 군집을 비교해볼까요?
#
# ### **숙제 정보**
#
# ■ 난이도 : 🟡중
#
# ■ 실습 범위 : 4주차
#
# ■ 사용 언어 및 라이브러리 : pandas, scikit-learn

# %%
#라이브러리 임포트
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
#데이터 로드
train_data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
#데이터 출력
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
