# %% [markdown]
# ### **OX 퀴즈 시간!**
#
# > 1주차에서 배운 내용을 토대로 문제를 풀어보세요 😉
# >
#
# ### 문제:
#
# 1. 머신러닝은 사람처럼 생각하고 행동하는 기술을 의미한다. (O/X)
# 2. 딥러닝은 머신러닝의 한 분야로, 이미지 인식이나 자연어 처리에 뛰어나다. (O/X)
# 3. 머신러닝에서는 수학 공식에 대한 깊은 이해가 필수적이다. (O/X)
# 4. 머신러닝의 구성요소에는 데이터셋, 특징(Feature), 레이블이 포함된다. (O/X)
# 5. 전통적인 프로그래밍은 데이터를 통해 스스로 학습하고 예측하는 능력을 갖춘다. (O/X)
# 6. 지도 학습은 레이블이 없는 데이터셋을 이용하여 모델을 학습시키는 방법이다. (O/X)
# 7. 배깅(Bagging)은 여러 모델을 독립적으로 학습시키고 예측을 평균내거나 다수결 투표로 최종 예측을 수행한다. (O/X)
# 8. 과적합(Overfitting)은 모델이 훈련 데이터에 지나치게 적응하여 새로운 데이터에 대한 일반화 성능이 떨어지는 현상이다. (O/X)
# 9. 모든 데이터셋에 대해 완벽한 성능을 보이는 모델이 존재한다. (O/X)
#
# ### **숙제 정보**
#
# ■ 난이도 : 🟢하
#
# ■ 실습 범위 : 1주차
#
# ---

# %% [markdown]
# ## 1. 머신러닝은 사람처럼 생각하고 행동하는 기술을 의미한다.
# <br/>
# 정답: X
# <br/>
# 설명: 머신러닝은 사람처럼 생각하거나 행동하는 것이 아니라, 데이터를 기반으로 패턴을 학습하여 예측하거나 결정을 내리는 기술임. 사람처럼 생각하고 행동하는 것은 인공지능(AI)의 목표 중 하나이지만, 머신러닝을 데이터에서 학습하는 알고리즘을 의미.
# <br/>
# <strong>정답</strong>

# %% [markdown]
# ## 2. 딥러닝은 머신러닝의 한 분야로, 이미지 인식이나 자연어 처리에 뛰어나다.
# <br/>
# 정답: O
# <br/>
# 설명: 딥러닝은 머신러닝의 하위 분야로, 특히 이미지 인식, 음성 인식, 자연어 처리와 같은 분야에서 뛰어난 성능을 보여줌. 딥러닝 모델은 신경망을 사용하여 복잡한 패턴을 학습함.
# <br/>
# <strong>정답</strong>

# %% [markdown]
# ## 3. 머신러닝에서는 수학 공식에 대한 깊은 이해가 필수적이다.
# <br/>
# 정답: X
# <br/>
# 설명: 머신러닝 알고리즘은 수학적 개념을 기반으로 하며, 확률, 미적분, 선형대수와 같은 수학적인 기초를 이해하는 것이 매우 중요. 특히 모델의 작동 원리와 성능을 최적화하는 데 수학적인 지식이 필요.
# <br/>
# <strong>오답</strong>
# <br/>
# <strong>정답은 O</strong>

# %% [markdown]
# ## 4. 머신러닝의 구성요소에는 데이터셋, 특징(feature), 레이블이 포함된다.
# <br/>
# 정답: O
# <br/>
# 설명: 머신러닝의 주요 구성요소는 데이터셋(학습할 데이터), 특징(Feature, 데이터의 특성), 그리고 레이블(정답)임. 특히 지도 학습에서는 레이블이 중요한 역할을 함.
# <br/>
# <strong>정답</strong>

# %% [markdown]
# ## 5. 전통적인 프로그래밍은 데이터를 통해 스스로 학습하고 예측하는 능력을 갖춘다.
# <br/>
# 정답: X
# <br/>
# 설명: 전동적인 프로그래밍에서는 사람이 명시적으로 규칙을 프로그램에 작성하여 동작함. 반면, 머신러닝은 데이터를 기반으로 스스로 학습하고 예측하는 모델을 구축하는 것이 특징.
# <br/>
# <strong>정답</strong>

# %% [markdown]
# ## 6. 지도 학습은 레이블이 없는 데이터셋을 이용하여 모델을 학습시키는 방법이다.
# <br/>
# 정답: ?
# <br/>
# 설명: 지도 학습은 레이블이 있는 데이터셋을 이용하여 모델을 학습시킴. 레이블이 없는 데이터셋을 이용하는 학습 방식은 비지도학습임.
# <br/>
# 틀린 이유: 레이블이 뭔지 몰랐음. 레이블: 정답
# <br/>
# <strong>오답(못품)</strong>
# <br/>
# <strong>정답은 X</strong>

# %% [markdown]
# ## 7. 배깅(Bagging)은 여러 모델을 독립적으로 학습시키고 예측을 평균내거나 다수결 투표로 최종 예측을 수행한다.
# <br/>
# 정답: ?
# <br/>
# 설명: 배깅(Bagging)은 앙상블 학습 기법 중 하나로, 여러 모델을 독립적으로 학습시킨 후, 그 예측 결과를 평균내거나 다수결 투표로 최종 예측을 만듦. 랜덤 포레스트가 배깅의 대표적인 예
# <br/>
# <strong>오답(못품)</strong>
# <br/>
# <strong>정답은 O</strong>

# %% [markdown]
# ## 8. 과적합(Overfitting)은 모델이 훈련 데이터에 지나치게 적응하여 새로운 데이터에 대한 일반화 성능이 떨어지는 현상이다.
# <br/>
# 정답: O
# <br/>
# 설명: 과적합은 모델이 훈련 데이터에 너무 특화되어 학습된 경우로, 새로운 데이터에 대한 일반화 성능이 떨어지는 문제를 일으킴. 과적합은 일반적으로 모델이 지나치게 복잡하거나 데이터가 충분하지 않을 때 발생
# <br/>
# <strong>정답</strong>

# %% [markdown]
# ## 9. 모든 데이터셋에 대해 완벽한 성능을 보이는 모델이 존재한다.
# <br/>
# 정답: X
# <br/>
# 설명: 모든 데이터셋에 완벽한 성능을 보이는 존재하지 않음. 이는 No Free Lunch Theorem 이론에 의해 설명되며,특정 데이터에 잘 맞는 모델이 다른 데이터에 대해서도 잘 동작한다고 보장할 수없음.
# <br/>
# <strong>정답</strong>
